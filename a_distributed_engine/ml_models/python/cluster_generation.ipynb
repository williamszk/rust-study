# %%
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import pandas as pd

# alt.renderers.enable('notebook')

# %%
array = np.load("./cluster_smoke_check.npy")

# %%
source = pd.DataFrame({"x": array[:, 0], "y": array[:, 1]})

alt.Chart(source).mark_circle(size=60).encode(
    x='x',
    y='y',
).interactive()
# Out:
# alt.Chart(...)
